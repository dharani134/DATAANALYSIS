# %%
pip install pandas

# %%
import pandas as pd
a=["Jwalitha","Ramya","Durga","Jahnavi","Lahari","Rajesh","Kannan"]
r=pd.Series(a,index=[67,43,44,89,34,45,23])
print(r)
# Out:
# 67    Jwalitha
# 43       Ramya
# 44       Durga
# 89     Jahnavi
# 34      Lahari
# 45      Rajesh
# 23      Kannan
# dtype: object

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
print(df)
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# ..           ...         ...  ..      ...    ...     ...      ...
# 85            85          85  29   no fat    135  15 min  running
# 86            86          86  29   no fat    130  30 min  running
# 87            87          87  30   no fat     99   1 min  running
# 88            88          88  30   no fat    111  15 min  running
# 89            89          89  30   no fat    150  30 min  running
#
# [90 rows x 7 columns]

# %%
df=pd.read_csv("/content/exercisedatabase.csv",sep="\t")
print(df)
# Out:
#    ,Unnamed: 0,id,diet,pulse,time,kind
# 0          0,0,1,low fat,85,1 min,rest
# 1         1,1,1,low fat,85,15 min,rest
# 2         2,2,1,low fat,88,30 min,rest
# 3          3,3,2,low fat,90,1 min,rest
# 4         4,4,2,low fat,92,15 min,rest
# ..                                 ...
# 85  85,85,29,no fat,135,15 min,running
# 86  86,86,29,no fat,130,30 min,running
# 87    87,87,30,no fat,99,1 min,running
# 88  88,88,30,no fat,111,15 min,running
# 89  89,89,30,no fat,150,30 min,running
#
# [90 rows x 1 columns]

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
print(df)
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# ..           ...         ...  ..      ...    ...     ...      ...
# 85            85          85  29   no fat    135  15 min  running
# 86            86          86  29   no fat    130  30 min  running
# 87            87          87  30   no fat     99   1 min  running
# 88            88          88  30   no fat    111  15 min  running
# 89            89          89  30   no fat    150  30 min  running
#
# [90 rows x 7 columns]

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
print(df.head())
print(df.tail(n=10))
# Out:
#    Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 0             0           0   1  low fat     85   1 min  rest
# 1             1           1   1  low fat     85  15 min  rest
# 2             2           2   1  low fat     88  30 min  rest
# 3             3           3   2  low fat     90   1 min  rest
# 4             4           4   2  low fat     92  15 min  rest
#     Unnamed: 0.1  Unnamed: 0  id    diet  pulse    time     kind
# 80            80          80  27  no fat    140  30 min  running
# 81            81          81  28  no fat    103   1 min  running
# 82            82          82  28  no fat    124  15 min  running
# 83            83          83  28  no fat    140  30 min  running
# 84            84          84  29  no fat     94   1 min  running
# 85            85          85  29  no fat    135  15 min  running
# 86            86          86  29  no fat    130  30 min  running
# 87            87          87  30  no fat     99   1 min  running
# ...

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
print(df.describe())
# Out:
#        Unnamed: 0.1  Unnamed: 0         id       pulse
# count     90.000000   90.000000  90.000000   90.000000
# mean      44.500000   44.500000  15.500000   99.700000
# std       26.124701   26.124701   8.703932   14.858471
# min        0.000000    0.000000   1.000000   80.000000
# 25%       22.250000   22.250000   8.000000   90.250000
# 50%       44.500000   44.500000  15.500000   96.000000
# 75%       66.750000   66.750000  23.000000  103.000000
# max       89.000000   89.000000  30.000000  150.000000

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
print(df.describe().T)
# Out:
#               count  mean        std   min    25%   50%     75%    max
# Unnamed: 0.1   90.0  44.5  26.124701   0.0  22.25  44.5   66.75   89.0
# Unnamed: 0     90.0  44.5  26.124701   0.0  22.25  44.5   66.75   89.0
# id             90.0  15.5   8.703932   1.0   8.00  15.5   23.00   30.0
# pulse          90.0  99.7  14.858471  80.0  90.25  96.0  103.00  150.0

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (90, 7)
# 90
# 7

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
print(df.columns)
l1=list(df.columns)
print(l1)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')
# ['Unnamed: 0.1', 'Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind']

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
df2=df.copy()
df2.loc[2:5,'pulse']=None
df2.head(7)
# Out:
#    Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 0             0           0   1  low fat   85.0   1 min  rest
# 1             1           1   1  low fat   85.0  15 min  rest
# 2             2           2   1  low fat    NaN  30 min  rest
# 3             3           3   2  low fat    NaN   1 min  rest
# 4             4           4   2  low fat    NaN  15 min  rest
# 5             5           5   2  low fat    NaN  30 min  rest
# 6             6           6   3  low fat   97.0   1 min  rest

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
df2=df.copy()
df2.loc[2:5,'pulse']=8
df2.head(7)
# Out:
#    Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 0             0           0   1  low fat     85   1 min  rest
# 1             1           1   1  low fat     85  15 min  rest
# 2             2           2   1  low fat      8  30 min  rest
# 3             3           3   2  low fat      8   1 min  rest
# 4             4           4   2  low fat      8  15 min  rest
# 5             5           5   2  low fat      8  30 min  rest
# 6             6           6   3  low fat     97   1 min  rest

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
df2=df.copy()
df2.loc[2:5,'pulse']=8
df2.head(7)
df2.isnull().head(7)
# Out:
#    Unnamed: 0.1  Unnamed: 0     id   diet  pulse   time   kind
# 0         False       False  False  False  False  False  False
# 1         False       False  False  False  False  False  False
# 2         False       False  False  False  False  False  False
# 3         False       False  False  False  False  False  False
# 4         False       False  False  False  False  False  False
# 5         False       False  False  False  False  False  False
# 6         False       False  False  False  False  False  False

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
df2=df.copy()
df2.loc[2:5,'pulse']=8
df2.head(7)
df2.isnull().head(7)
df2.isnull().tail(7)
# Out:
#     Unnamed: 0.1  Unnamed: 0     id   diet  pulse   time   kind
# 83         False       False  False  False  False  False  False
# 84         False       False  False  False  False  False  False
# 85         False       False  False  False  False  False  False
# 86         False       False  False  False  False  False  False
# 87         False       False  False  False  False  False  False
# 88         False       False  False  False  False  False  False
# 89         False       False  False  False  False  False  False

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
df2=df.copy()
df2.loc[2:5,'pulse']=None
df2.head(7)
df2.isnull().head(7)
df2.isnull().tail(7)
print(df2.isnull().sum())
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# id              0
# diet            0
# pulse           4
# time            0
# kind            0
# dtype: int64

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
df2=df.copy()
df2.loc[2:5,'pulse']=None
df2.head(7)
df2.isnull().head(7)
df2.isnull().tail(7)
print(df2.isnull().sum())
print(df2['pulse'])
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# id              0
# diet            0
# pulse           4
# time            0
# kind            0
# dtype: int64
# 0      85.0
# 1      85.0
# 2       NaN
# 3       NaN
# 4       NaN
#       ...
# 85    135.0
# 86    130.0
# 87     99.0
# 88    111.0
# 89    150.0
# Name: pulse, Length: 90, dtype: float64

# %%
df=pd.read_csv("/content/exercisedatabase.csv")
df2=df.copy()
df2.loc[2:5,'pulse']
df2.head(7)
df2.isnull().head(7)
df2.isnull().tail(7)
print(df2.isnull().sum())
print(df2[['pulse','id']])
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# id              0
# diet            0
# pulse           0
# time            0
# kind            0
# dtype: int64
#     pulse  id
# 0      85   1
# 1      85   1
# 2      88   1
# 3      90   2
# 4      92   2
# ..    ...  ..
# 85    135  29
# 86    130  29
# 87     99  30
# 88    111  30
# 89    150  30
#
# [90 rows x 2 columns]

# %%
print(df[df.index==1])
# Out:
#    Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 1             1           1   1  low fat     85  15 min  rest

# %%
print(df[df.index.isin(range(2,5))])
# Out:
#    Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 2             2           2   1  low fat     88  30 min  rest
# 3             3           3   2  low fat     90   1 min  rest
# 4             4           4   2  low fat     92  15 min  rest

# %%
print(df2.loc[1])
# Out:
# Unnamed: 0.1          1
# Unnamed: 0            1
# id                    1
# diet            low fat
# pulse                85
# time             15 min
# kind               rest
# Name: 1, dtype: object

# %%
print(df2.loc[3])
# Out:
# Unnamed: 0.1          3
# Unnamed: 0            3
# id                    2
# diet            low fat
# pulse                90
# time              1 min
# kind               rest
# Name: 3, dtype: object

# %%
df2.loc[6:11]
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 6              6           6   3  low fat     97   1 min  rest
# 7              7           7   3  low fat     97  15 min  rest
# 8              8           8   3  low fat     94  30 min  rest
# 9              9           9   4  low fat     80   1 min  rest
# 10            10          10   4  low fat     82  15 min  rest
# 11            11          11   4  low fat     83  30 min  rest

# %%
df2.loc[6:11,'pulse']
print(df2)
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# ..           ...         ...  ..      ...    ...     ...      ...
# 85            85          85  29   no fat    135  15 min  running
# 86            86          86  29   no fat    130  30 min  running
# 87            87          87  30   no fat     99   1 min  running
# 88            88          88  30   no fat    111  15 min  running
# 89            89          89  30   no fat    150  30 min  running
#
# [90 rows x 7 columns]

# %%
df2.loc[[10,2,7]]
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 10            10          10   4  low fat     82  15 min  rest
# 2              2           2   1  low fat     88  30 min  rest
# 7              7           7   3  low fat     97  15 min  rest

# %%
 df2.loc[10:15,['id','diet',]]
# Out:
#     id     diet
# 10   4  low fat
# 11   4  low fat
# 12   5  low fat
# 13   5  low fat
# 14   5  low fat
# 15   6   no fat

# %%
 df2.loc[[1,2,3]]
# Out:
#    Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time  kind
# 1             1           1   1  low fat     85  15 min  rest
# 2             2           2   1  low fat     88  30 min  rest
# 3             3           3   2  low fat     90   1 min  rest

# %%
df2.iloc[10:14,:3]
# Out:
#     Unnamed: 0.1  Unnamed: 0  id
# 10            10          10   4
# 11            11          11   4
# 12            12          12   5
# 13            13          13   5

# %%
df2.loc[:7,["id"]]
# Out:
#    id
# 0   1
# 1   1
# 2   1
# 3   2
# 4   2
# 5   2
# 6   3
# 7   3

# %%
df2.loc[df['diet']=='low fat']
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# 5              5           5   2  low fat     93  30 min     rest
# 6              6           6   3  low fat     97   1 min     rest
# 7              7           7   3  low fat     97  15 min     rest
# 8              8           8   3  low fat     94  30 min     rest
# 9              9           9   4  low fat     80   1 min     rest
# 10            10          10   4  low fat     82  15 min     rest
# 11            11          11   4  low fat     83  30 min     rest
# 12            12          12   5  low fat     91   1 min     rest
# ...

# %%
df3=df2.copy()
#df3=df3.dropna()
df3
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# ..           ...         ...  ..      ...    ...     ...      ...
# 85            85          85  29   no fat    135  15 min  running
# 86            86          86  29   no fat    130  30 min  running
# 87            87          87  30   no fat     99   1 min  running
# 88            88          88  30   no fat    111  15 min  running
# 89            89          89  30   no fat    150  30 min  running
#
# [90 rows x 7 columns]

# %%
df3.dropna(inplace=True,axis=1)
df3
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# ..           ...         ...  ..      ...    ...     ...      ...
# 85            85          85  29   no fat    135  15 min  running
# 86            86          86  29   no fat    130  30 min  running
# 87            87          87  30   no fat     99   1 min  running
# 88            88          88  30   no fat    111  15 min  running
# 89            89          89  30   no fat    150  30 min  running
#
# [90 rows x 7 columns]

# %%
df3.dropna(inplace=True,how='all')
df3
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# ..           ...         ...  ..      ...    ...     ...      ...
# 85            85          85  29   no fat    135  15 min  running
# 86            86          86  29   no fat    130  30 min  running
# 87            87          87  30   no fat     99   1 min  running
# 88            88          88  30   no fat    111  15 min  running
# 89            89          89  30   no fat    150  30 min  running
#
# [90 rows x 7 columns]

# %%
mv=df['pulse
'].mean()
df=df.fillna(mv)
print(df)
# Out:
#     Unnamed: 0.1  Unnamed: 0  id     diet  pulse    time     kind
# 0              0           0   1  low fat     85   1 min     rest
# 1              1           1   1  low fat     85  15 min     rest
# 2              2           2   1  low fat     88  30 min     rest
# 3              3           3   2  low fat     90   1 min     rest
# 4              4           4   2  low fat     92  15 min     rest
# ..           ...         ...  ..      ...    ...     ...      ...
# 85            85          85  29   no fat    135  15 min  running
# 86            86          86  29   no fat    130  30 min  running
# 87            87          87  30   no fat     99   1 min  running
# 88            88          88  30   no fat    111  15 min  running
# 89            89          89  30   no fat    150  30 min  running
#
# [90 rows x 7 columns]
